# %% [markdown]
# <a href="https://colab.research.google.com/github/sidd1311/Machine-Learning/blob/main/ML_EXP_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
A = np.array([[5, 8, 16],
              [4, 1, 8],
              [-4, -4, -11]])

# %%
eigenvalues, eigenvectors = np.linalg.eig(A)

# %%
print("Eigenvalues:", eigenvalues)
print("Eigenvectors:\n", eigenvectors)
# Out:
# Eigenvalues: [ 1.+0.00000000e+00j -3.+2.71947991e-15j -3.-2.71947991e-15j]
# Eigenvectors:
#  [[ 0.81649658+0.j          0.14036888-0.55580947j  0.14036888+0.55580947j]
#  [ 0.40824829+0.j         -0.71521317+0.j         -0.71521317-0.j        ]
#  [-0.40824829+0.j          0.28742215+0.27790473j  0.28742215-0.27790473j]]

# %%
import seaborn as sns
from sklearn.decomposition import PCA

# %%
data = np.array([[2, 3, 4, 5, 6, 7],
                 [1, 5, 3, 6, 7, 8]])
pca = PCA(n_components=1)

# %%
iris = load_iris()
X = iris.data
Y = iris.target

# %%
pca_iris = PCA(n_components=2)
X_pca = pca_iris.fit_transform(X)

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette='viridis')
plt.title('First Two Principal Components of IRIS Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.hist(X_pca[:, 0], bins=20, alpha=0.7, label='PC 1')
plt.hist(X_pca[:, 1], bins=20, alpha=0.7, label='PC 2')
plt.title('Distribution of Principal Components')
plt.xlabel('Principal Component Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
