# %% [markdown]
# <a href="https://colab.research.google.com/github/sidd1311/Machine-Learning/blob/main/ML_EXP_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# ...

# %%
num_plots = sum(range(len(data.columns[:-1])))
plt.figure(figsize=(15, 12))
plot_number = 1
for i, col1 in enumerate(data.columns[:-1]):
    for col2 in data.columns[i+1:-1]:
        plt.subplot(6, 4, plot_number)
        sns.scatterplot(x=col1, y=col2, data=data)
        plt.title(f'{col1} vs {col2}')
        plot_number += 1
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)
plt.suptitle('Pair Plot', y=1.02)
plt.show()

# %%
plt.figure(figsize=(12, 10))
plot_number = 1
for col in data.columns[:-1]:
    plt.subplot(4, 4, plot_number)
    sns.histplot(data[col], kde=True, bins=15)  # Added bins parameter for better distribution clarity
    plt.title(f'{col} Distribution')
    plot_number += 1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))
plot_number = 1
for col in data.columns[:-1]:
    plt.subplot(4, 4, plot_number)
    sns.histplot(data[col], kde=True, bins=5)  # Added bins parameter for better distribution clarity
    plt.title(f'{col} Distribution')
    plot_number += 1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))
plot_number = 1
for col in data.columns[:-1]:
    plt.subplot(4, 4, plot_number)
    sns.histplot(data[col], kde=True, bins=20)  # Added bins parameter for better distribution clarity
    plt.title(f'{col} Distribution')
    plot_number += 1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 15))
plot_number = 1
for col in data.columns[:-1]:
    plt.subplot(6, 4, plot_number)
    sns.boxplot(x='Outcome', y=col, data=data)
    plt.title(f'{col} by Outcome (Box Plot)')
    plot_number += 1
plt.tight_layout()
plt.show()

# %%
print(f"Dataset Shape: {data.shape}")
# Out:
# Dataset Shape: (768, 8)

# %%
glucose_bp_zero = data[['Glucose', 'BloodPressure']][data['Outcome'] == 0]
print("Glucose and Blood Pressure where Outcome is 0:")
print(glucose_bp_zero)
# Out:
# Glucose and Blood Pressure where Outcome is 0:
#      Glucose  BloodPressure
# 1         85             66
# 3         89             66
# 5        116             74
# 7        115              0
# 10       110             92
# ..       ...            ...
# 762       89             62
# 763      101             76
# 764      122             70
# 765      121             72
# 767       93             70
#
# [500 rows x 2 columns]

# %%
bmi_skin_insulin_one = data[['BMI', 'SkinThickness', 'Insulin']][data['Outcome'] == 1]
print("BMI, SkinThickness, and Insulin where Outcome is 1:")
print(bmi_skin_insulin_one)
# Out:
# BMI, SkinThickness, and Insulin where Outcome is 1:
#       BMI  SkinThickness  Insulin
# 0    33.6             35        0
# 2    23.3              0        0
# 4    43.1             35      168
# 6    31.0             32       88
# 8    30.5             45      543
# ..    ...            ...      ...
# 755  36.5             39      110
# 757  36.3              0        0
# 759  35.5              0        0
# 761  44.0             31        0
# 766  30.1              0        0
#
# [268 rows x 3 columns]

# %%
insulin_zero_outcome = data[['Insulin', 'Outcome']][data['Insulin'] == 0]
print("Outcome where Insulin is 0:")
print(insulin_zero_outcome)
# Out:
# Outcome where Insulin is 0:
#      Insulin  Outcome
# 0          0        1
# 1          0        0
# 2          0        1
# 5          0        0
# 7          0        0
# ..       ...      ...
# 761        0        1
# 762        0        0
# 764        0        0
# 766        0        1
# 767        0        0
#
# [374 rows x 2 columns]

# %%
glucose_150_data = data[['Age', 'Outcome']][data['Glucose'] == 150]
print("Age and Outcome where Glucose is 150:")
print(glucose_150_data)
# Out:
# Age and Outcome where Glucose is 150:
#      Age  Outcome
# 54    42        0
# 304   37        0
# 603   54        1

# %%
bp_range_data = data[['Age', 'Glucose']][(data['BloodPressure'] > 70) & (data['BloodPressure'] < 90)]
print("Age and Glucose where 70 < BloodPressure < 90:")
print(bp_range_data)
# Out:
# Age and Glucose where 70 < BloodPressure < 90:
#      Age  Glucose
# 0     50      148
# 5     30      116
# 11    34      168
# 12    57      139
# 14    51      166
# ..   ...      ...
# 757   52      123
# 758   26      106
# 761   43      170
# 763   63      101
# 765   30      121
#
# [333 rows x 2 columns]
